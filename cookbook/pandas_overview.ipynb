# %% [markdown]
# [Back to Index](index.ipynb)

# %% [markdown]
# # A quick overview of working with Pandas

# %% [markdown]
# Begin by importing all python modules we will need. For this exercise we will use Pandas.
#
# Pandas is a popular open source Python library for data analysis. It introduces two new data structures to Python - Series and DataFrame, both of which are built on top of NumPy (this means it's fast).
# - [Series](http://pandas.pydata.org/pandas-docs/version/0.15.2/dsintro.html#basicsseries) is a one-dimensional labeled array capable of holding any data type (integers, strings, floating point numbers, Python objects, etc.).
# - [DataFrame](http://pandas.pydata.org/pandas-docs/version/0.15.2/dsintro.html#basics-dataframe) is a 2-dimensional labeled data structure with columns of potentially different types. You can think of it like a spreadsheet or SQL table, or a dict of Series objects.
#
# Pandas is also tightly integrated with [matplotlib](http://pandas.pydata.org/pandas-docs/version/0.15.2/visualization.html) and you can do basic plotting directly from a dataframe. It also provides functionality for applying complex transformations and filters to the data and much more. There are lot of great Pandas tutorials on the web, here is one - [An Introduction to Pandas](http://synesthesiam.com/posts/an-introduction-to-pandas.html)

# %%
# A 'magic' command to display plots inline
# %matplotlib inline

import requests
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Create a Pandas DataFrame
#
# We will create a new Pandas DataFrame from a timeseries. Let's get the tiemseries for Annual Average Maximum Temperature for one model (CNRM-CM5) and one scenario (RCP 4.5) for Sacramento County.

# %%
url = 'http://api.cal-adapt.org/api/series/tasmax_year_CNRM-CM5_rcp45/rasters/?pagesize=100&stat=mean&ref=/api/counties/34/'

# Make request
response = requests.get(url)
# Get json from response object
data = response.json()

# Create a new pandas dataframe. 
df = pd.DataFrame(data['results'])
df
# Out:
#          event                                               geom  height  \
# 0   2006-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 1   2007-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 2   2008-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 3   2009-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 4   2010-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 5   2011-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 6   2012-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 7   2013-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 8   2014-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 9   2015-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 10  2016-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 11  2017-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 12  2018-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 13  2019-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 14  2020-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 15  2021-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 16  2022-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 17  2023-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 18  2024-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 19  2025-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 20  2026-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 21  2027-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 22  2028-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 23  2029-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 24  2030-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 25  2031-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 26  2032-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 27  2033-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 28  2034-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 29  2035-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# ..         ...                                                ...     ...
# 65  2071-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 66  2072-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 67  2073-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 68  2074-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 69  2075-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 70  2076-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 71  2077-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 72  2078-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 73  2079-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 74  2080-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 75  2081-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 76  2082-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 77  2083-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 78  2084-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 79  2085-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 80  2086-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 81  2087-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 82  2088-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 83  2089-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 84  2090-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 85  2091-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 86  2092-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 87  2093-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 88  2094-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 89  2095-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 90  2096-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 91  2097-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 92  2098-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 93  2099-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
# 94  2100-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195
#
#        id       image      maxval      minval  \
# 0   10521  297.956266  307.180908  279.125122
# 1   10522  297.892679  307.524902  278.383301
# 2   10523  297.923003  306.061737  278.244751
# 3   10524  297.139457  306.723663  277.725647
# 4   10525  298.715327  307.107422  279.637146
# 5   10526  297.821621  306.439636  278.275024
# 6   10527  297.977348  307.351990  278.537384
# 7   10528  298.436654  307.039032  278.542999
# 8   10529  298.029921  306.381927  278.373047
# 9   10530  297.039505  306.650696  277.664246
# 10  10531  297.567735  306.298401  277.175232
# 11  10532  297.773860  306.666016  278.062805
# 12  10533  296.847858  306.041656  277.258179
# 13  10534  297.872503  307.031830  278.272736
# 14  10535  296.512001  306.509705  276.985748
# 15  10536  296.984657  306.313995  276.722168
# 16  10537  297.728818  307.064667  277.855133
# 17  10538  298.069306  306.700317  278.574860
# 11  tasmax_year_CNRM-CM5_rcp45_2017
# 12  tasmax_year_CNRM-CM5_rcp45_2018
# 13  tasmax_year_CNRM-CM5_rcp45_2019
# 14  tasmax_year_CNRM-CM5_rcp45_2020
# 15  tasmax_year_CNRM-CM5_rcp45_2021
# 16  tasmax_year_CNRM-CM5_rcp45_2022
# 17  tasmax_year_CNRM-CM5_rcp45_2023
# 18  tasmax_year_CNRM-CM5_rcp45_2024
# 19  tasmax_year_CNRM-CM5_rcp45_2025
# 20  tasmax_year_CNRM-CM5_rcp45_2026
# 21  tasmax_year_CNRM-CM5_rcp45_2027
# 22  tasmax_year_CNRM-CM5_rcp45_2028
# 23  tasmax_year_CNRM-CM5_rcp45_2029
# 24  tasmax_year_CNRM-CM5_rcp45_2030
# 25  tasmax_year_CNRM-CM5_rcp45_2031
# 26  tasmax_year_CNRM-CM5_rcp45_2032
# 27  tasmax_year_CNRM-CM5_rcp45_2033
# 28  tasmax_year_CNRM-CM5_rcp45_2034
# 29  tasmax_year_CNRM-CM5_rcp45_2035
# ..                              ...
# 65  tasmax_year_CNRM-CM5_rcp45_2071
# 66  tasmax_year_CNRM-CM5_rcp45_2072
# 67  tasmax_year_CNRM-CM5_rcp45_2073
# 68  tasmax_year_CNRM-CM5_rcp45_2074
# 69  tasmax_year_CNRM-CM5_rcp45_2075
# 70  tasmax_year_CNRM-CM5_rcp45_2076
# 71  tasmax_year_CNRM-CM5_rcp45_2077
# 72  tasmax_year_CNRM-CM5_rcp45_2078
# 73  tasmax_year_CNRM-CM5_rcp45_2079
# 74  tasmax_year_CNRM-CM5_rcp45_2080
# 75  tasmax_year_CNRM-CM5_rcp45_2081
# 76  tasmax_year_CNRM-CM5_rcp45_2082
# 77  tasmax_year_CNRM-CM5_rcp45_2083
# 78  tasmax_year_CNRM-CM5_rcp45_2084
# 79  tasmax_year_CNRM-CM5_rcp45_2085
# 80  tasmax_year_CNRM-CM5_rcp45_2086
# 81  tasmax_year_CNRM-CM5_rcp45_2087
# 82  tasmax_year_CNRM-CM5_rcp45_2088
# 83  tasmax_year_CNRM-CM5_rcp45_2089
# 84  tasmax_year_CNRM-CM5_rcp45_2090
# 85  tasmax_year_CNRM-CM5_rcp45_2091
# 86  tasmax_year_CNRM-CM5_rcp45_2092
# 87  tasmax_year_CNRM-CM5_rcp45_2093
# 88  tasmax_year_CNRM-CM5_rcp45_2094
# 89  tasmax_year_CNRM-CM5_rcp45_2095
# 90  tasmax_year_CNRM-CM5_rcp45_2096
# 91  tasmax_year_CNRM-CM5_rcp45_2097
# 92  tasmax_year_CNRM-CM5_rcp45_2098
# 93  tasmax_year_CNRM-CM5_rcp45_2099
# 94  tasmax_year_CNRM-CM5_rcp45_2100
#
#                                                   srs  \
# 0   GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 1   GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 2   GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 3   GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 4   GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 5   GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 6   GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 7   GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 8   GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 9   GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 10  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 11  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 12  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 13  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 14  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 15  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 16  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 17  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 18  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 19  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 20  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 21  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 22  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 23  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 24  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 25  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 26  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 27  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 28  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 29  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# ..                                                ...
# 65  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 66  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 67  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 68  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 69  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 70  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 71  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 72  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 73  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 74  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 75  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 76  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 77  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 78  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 79  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 80  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 81  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 82  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 83  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 84  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 85  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 86  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 87  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 88  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 89  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 90  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 91  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 92  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 93  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 94  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
#
#                                               tileurl units  \
# 0   http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 1   http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 2   http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 3   http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 4   http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 5   http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 6   http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 7   http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 8   http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 9   http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 10  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 11  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 12  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 13  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 14  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 15  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 16  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 17  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 18  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 19  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 20  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 21  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 22  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 23  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 24  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 25  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 26  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 27  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 28  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 29  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# ..                                                ...   ...
# 65  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 66  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 67  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 68  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 69  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 70  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 71  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 72  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 73  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 74  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 75  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 76  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 77  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 78  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 79  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 80  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 81  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 82  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 83  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 84  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 85  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 86  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 87  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 88  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 89  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 90  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 91  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 92  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 93  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 94  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
#
#                                                   url  width  xpixsize  \
# 0   http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 1   http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 2   http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 3   http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 4   http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 5   http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 6   http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 7   http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 8   http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 9   http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 10  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 11  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 12  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 13  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 14  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 15  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 16  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 17  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 18  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 19  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 20  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 21  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 22  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 23  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 24  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 25  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 26  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 27  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 28  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 29  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# ..                                                ...    ...       ...
# 65  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 66  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 67  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 68  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 69  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 70  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 71  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 72  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 73  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 74  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 75  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 76  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 77  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 78  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 79  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 80  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 81  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 82  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 83  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 84  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 85  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 86  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 87  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 88  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 89  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 90  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 91  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 92  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 93  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
# 94  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179    0.0625
#
#     ypixsize
# 0    -0.0625
# 1    -0.0625
# 2    -0.0625
# 3    -0.0625
# 4    -0.0625
# 5    -0.0625
# 6    -0.0625
# 7    -0.0625
# 8    -0.0625
# 9    -0.0625
# 10   -0.0625
# 11   -0.0625
# 12   -0.0625
# 13   -0.0625
# 14   -0.0625
# 15   -0.0625
# 16   -0.0625
# 17   -0.0625
# 18   -0.0625
# 19   -0.0625
# 20   -0.0625
# 21   -0.0625
# 22   -0.0625
# 23   -0.0625
# 24   -0.0625
# 25   -0.0625
# 26   -0.0625
# 27   -0.0625
# 28   -0.0625
# 29   -0.0625
# ..       ...
# 65   -0.0625
# 66   -0.0625
# 67   -0.0625
# 68   -0.0625
# 69   -0.0625
# 70   -0.0625
# 71   -0.0625
# 72   -0.0625
# 73   -0.0625
# 74   -0.0625
# 75   -0.0625
# 76   -0.0625
# 77   -0.0625
# 78   -0.0625
# 79   -0.0625
# 80   -0.0625
# 81   -0.0625
# 82   -0.0625
# 83   -0.0625
# 84   -0.0625
# 85   -0.0625
# 86   -0.0625
# 87   -0.0625
# 88   -0.0625
# 89   -0.0625
# 90   -0.0625
# 91   -0.0625
# 92   -0.0625
# 93   -0.0625
# 94   -0.0625
#
# [95 rows x 17 columns]

# %% [markdown]
# ### 2. Explore the data in a DataFrame
#
# Uncomment each one and examine the output

# %%
len(df)
df.head()
df.tail()
df.columns
df.image
df['image']
#df.event.head(20)
# Out:
# 0     297.956266
# 1     297.892679
# 2     297.923003
# 3     297.139457
# 4     298.715327
# 5     297.821621
# 6     297.977348
# 7     298.436654
# 8     298.029921
# 9     297.039505
# 10    297.567735
# 11    297.773860
# 12    296.847858
# 13    297.872503
# 14    296.512001
# 15    296.984657
# 16    297.728818
# 17    298.069306
# 18    298.069044
# 19    297.505396
# 20    297.768484
# 21    298.393243
# 22    297.327038
# 23    298.016511
# 24    298.395598
# 25    298.166056
# 26    297.496396
# 27    298.877980
# 28    298.272189
# 29    297.645659
#          ...
# 65    299.121335
# 66    299.827521
# 67    299.832474
# 68    299.403189
# 69    298.489932
# 70    300.113503
# 71    298.764296
# 72    298.965669
# 73    299.420023
# 74    298.761095
# 75    298.666720
# 76    299.948413
# 77    299.361187
# 78    299.395337
# 79    298.762464
# 80    300.198272
# 81    299.125544
# 82    298.651297
# 83    298.878161
# 84    298.539989
# 85    299.251188
# 86    299.635450
# 87    299.131222
# 88    299.851281
# 89    299.779096
# 90    299.194346
# 91    298.540593
# 92    299.543150
# 93    299.604744
# 94    299.237234
# Name: image, dtype: float64

# %% [markdown]
# ### 3. Apply functions to a DataFrame
#
# There are lots useful built-in methods we can use on a specific column, such as `mean()` to get the average. Most of pandas' methods will ignore missing values like NaN. You can also apply functions to all columns in a DataFrame. Try `std()`, `max()`, `min()`, `sum()`

# %%
df.image.mean()
df.mean()
# Out:
# height      1.950000e+02
# id          1.056800e+04
# image       2.985627e+02
# maxval      3.076297e+02
# minval      2.789376e+02
# nodata      1.000000e+30
# width       1.790000e+02
# xpixsize    6.250000e-02
# ypixsize   -6.250000e-02
# dtype: float64

# %% [markdown]
# You can also create custom functions. The `image` values in our dataframe are in Kelvin and we want to change them to degrees Fahrenheit. Let's create a function that does this conversion and apply it to each row in the `image` column using `.apply()`. An intro to [lambda](http://www.diveintopython.net/power_of_introspection/lambda_functions.html) functions in Python.

# %%
#df.image = df.image.apply(lambda x: (x - 273.15) * 9 / 5 + 32)
# For simple calculations you dont need to use apply
df.image = (df.image - 273.15) * 9 / 5 + 32

df.image.head()
# Out:
# 0    76.651279
# 1    76.536822
# 2    76.591405
# 3    75.181023
# 4    78.017589
# Name: image, dtype: float64

# %% [markdown]
# ### 4. Indexing
#
# Each row in a DataFrame has a unique identifier called the `index`. By default Pandas autogenerates an integer index for each row. But it can be useful to idenitfy each row by other indices.
#
# In our DateFrame each row represents max. temp for a year. The date (contained in the `event` field) is a unique identifier. We can tell the DataFrame to use the `event` field as the index field. This creates a timeseries and pandas provides some extra [functionality](https://tomaugspurger.github.io/modern-7-timeseries.html) for working with timeseries data.

# %%
# First change format of `event` field to datetime
df['event'] = pd.to_datetime(df['event'], format='%Y-%m-%d')
# Set event field as index
df = df.set_index(['event'])
# You can index by multiple fields

# %%
df.head(20)
# Out:
#                                                          geom  height     id  \
# event
# 2006-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195  10521
# 2007-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195  10522
# 2008-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195  10523
# 2009-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195  10524
# 2010-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195  10525
# 2011-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195  10526
# 2012-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195  10527
# 2013-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195  10528
# 2014-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195  10529
# 2015-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195  10530
# 2016-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195  10531
# 2017-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195  10532
# 2018-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195  10533
# 2019-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195  10534
# 2020-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195  10535
# 2021-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195  10536
# 2022-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195  10537
# 2023-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195  10538
# 2024-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195  10539
# 2025-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195  
01-01  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179
# 2017-01-01  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179
# 2018-01-01  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179
# 2019-01-01  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179
# 2020-01-01  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179
# 2021-01-01  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179
# 2022-01-01  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179
# 2023-01-01  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179
# 2024-01-01  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179
# 2025-01-01  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179
#
#             xpixsize  ypixsize
# event
# 2006-01-01    0.0625   -0.0625
# 2007-01-01    0.0625   -0.0625
# 2008-01-01    0.0625   -0.0625
# 2009-01-01    0.0625   -0.0625
# 2010-01-01    0.0625   -0.0625
# 2011-01-01    0.0625   -0.0625
# 2012-01-01    0.0625   -0.0625
# 2013-01-01    0.0625   -0.0625
# 2014-01-01    0.0625   -0.0625
# 2015-01-01    0.0625   -0.0625
# 2016-01-01    0.0625   -0.0625
# 2017-01-01    0.0625   -0.0625
# 2018-01-01    0.0625   -0.0625
# 2019-01-01    0.0625   -0.0625
# 2020-01-01    0.0625   -0.0625
# 2021-01-01    0.0625   -0.0625
# 2022-01-01    0.0625   -0.0625
# 2023-01-01    0.0625   -0.0625
# 2024-01-01    0.0625   -0.0625
# 2025-01-01    0.0625   -0.0625

# %% [markdown]
# ### 5. Filtering

# %%
# Filter by value
hi_temps = df[df.image >= 80]
hi_temps.head()

# Filter by time. Uncomment the following lines and run the cell again
filtered_df = df['20200101':'20300101']
filtered_df
# Out:
#                                                          geom  height     id  \
# event
# 2020-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195  10535
# 2021-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195  10536
# 2022-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195  10537
# 2023-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195  10538
# 2024-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195  10539
# 2025-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195  10540
# 2026-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195  10541
# 2027-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195  10542
# 2028-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195  10543
# 2029-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195  10544
# 2030-01-01  {'type': 'Polygon', 'coordinates': [[[-124.562...     195  10545
#
#                 image      maxval      minval  \
# event
# 2020-01-01  74.051601  306.509705  276.985748
# 2021-01-01  74.902382  306.313995  276.722168
# 2022-01-01  76.241872  307.064667  277.855133
# 2023-01-01  76.854750  306.700317  278.574860
# 2024-01-01  76.854279  306.933258  277.926056
# 2025-01-01  75.839713  306.716583  277.799316
# 2026-01-01  76.313272  306.882233  277.547333
# 2027-01-01  77.437837  306.856140  278.933258
# 2028-01-01  75.518668  306.509491  277.617035
# 2029-01-01  76.759720  307.261627  278.128479
# 2030-01-01  77.442077  307.184326  278.894379
#
#                                                          name        nodata  \
# event
# 2020-01-01  yearly average maximum temperature CNRM-CM5 RC...  1.000000e+30
# 2021-01-01  yearly average maximum temperature CNRM-CM5 RC...  1.000000e+30
# 2022-01-01  yearly average maximum temperature CNRM-CM5 RC...  1.000000e+30
# 2023-01-01  yearly average maximum temperature CNRM-CM5 RC...  1.000000e+30
# 2024-01-01  yearly average maximum temperature CNRM-CM5 RC...  1.000000e+30
# 2025-01-01  yearly average maximum temperature CNRM-CM5 RC...  1.000000e+30
# 2026-01-01  yearly average maximum temperature CNRM-CM5 RC...  1.000000e+30
# 2027-01-01  yearly average maximum temperature CNRM-CM5 RC...  1.000000e+30
# 2028-01-01  yearly average maximum temperature CNRM-CM5 RC...  1.000000e+30
# 2029-01-01  yearly average maximum temperature CNRM-CM5 RC...  1.000000e+30
# 2030-01-01  yearly average maximum temperature CNRM-CM5 RC...  1.000000e+30
#
#                                        slug  \
# event
# 2020-01-01  tasmax_year_CNRM-CM5_rcp45_2020
# 2021-01-01  tasmax_year_CNRM-CM5_rcp45_2021
# 2022-01-01  tasmax_year_CNRM-CM5_rcp45_2022
# 2023-01-01  tasmax_year_CNRM-CM5_rcp45_2023
# 2024-01-01  tasmax_year_CNRM-CM5_rcp45_2024
# 2025-01-01  tasmax_year_CNRM-CM5_rcp45_2025
# 2026-01-01  tasmax_year_CNRM-CM5_rcp45_2026
# 2027-01-01  tasmax_year_CNRM-CM5_rcp45_2027
# 2028-01-01  tasmax_year_CNRM-CM5_rcp45_2028
# 2029-01-01  tasmax_year_CNRM-CM5_rcp45_2029
# 2030-01-01  tasmax_year_CNRM-CM5_rcp45_2030
#
#                                                           srs  \
# event
# 2020-01-01  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 2021-01-01  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 2022-01-01  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 2023-01-01  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 2024-01-01  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 2025-01-01  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 2026-01-01  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 2027-01-01  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 2028-01-01  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 2029-01-01  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
# 2030-01-01  GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS...
#
#                                                       tileurl units  \
# event
# 2020-01-01  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 2021-01-01  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 2022-01-01  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 2023-01-01  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 2024-01-01  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 2025-01-01  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 2026-01-01  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 2027-01-01  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 2028-01-01  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 2029-01-01  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
# 2030-01-01  http://api.cal-adapt.org/tiles/tasmax_year_CNR...     K
#
#                                                           url  width  \
# event
# 2020-01-01  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179
# 2021-01-01  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179
# 2022-01-01  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179
# 2023-01-01  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179
# 2024-01-01  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179
# 2025-01-01  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179
# 2026-01-01  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179
# 2027-01-01  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179
# 2028-01-01  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179
# 2029-01-01  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179
# 2030-01-01  http://api.cal-adapt.org/api/rstores/tasmax_ye...    179
#
#             xpixsize  ypixsize
# event
# 2020-01-01    0.0625   -0.0625
# 2021-01-01    0.0625   -0.0625
# 2022-01-01    0.0625   -0.0625
# 2023-01-01    0.0625   -0.0625
# 2024-01-01    0.0625   -0.0625
# 2025-01-01    0.0625   -0.0625
# 2026-01-01    0.0625   -0.0625
# 2027-01-01    0.0625   -0.0625
# 2028-01-01    0.0625   -0.0625
# 2029-01-01    0.0625   -0.0625
# 2030-01-01    0.0625   -0.0625

# %% [markdown]
# ### 6. Resampling
#
# Resampling is similar to a groupby: you split the time series into groups (10 year bins below), apply a function to each group (mean), and combine the result (one row per group). This creates another data structure commonly used in Pandas called `Series` - a one-dimensional labeled array capable of holding any data type. See the pandas documentation for more examples of [resampling](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.resample.html).

# %%
# Only resample rows where year is between 2020 and 2099.
# 10AS refers to Annual, Start of Year. Refer to pandas docs for other ways to specify bins
decadal_avg = df['20100101':'20990101'].image.resample('10AS').mean()
print(type(decadal_avg))
decadal_avg
# Out:
# <class 'pandas.core.series.Series'>
# event
# 2010-01-01    76.384820
# 2020-01-01    76.077409
# 2030-01-01    76.868142
# 2040-01-01    77.431037
# 2050-01-01    77.889529
# 2060-01-01    78.465273
# 2070-01-01    79.121582
# 2080-01-01    78.844728
# 2090-01-01    79.082790
# Freq: 10AS-JAN, Name: image, dtype: float64

# %%
# The first row of the resampling result above is equivalent to:
df['20100101':'20190101'].image.mean()
# Out:
# 76.38481999033512

# %%
decadal_stats = df['20100101':'20990101'].image.resample('10AS').agg(['mean', 'max', 'min', 'std'])
print(type(decadal_stats))
decadal_stats
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                  mean        max        min       std
# event
# 2010-01-01  76.384820  78.017589  74.656144  1.016831
# 2020-01-01  76.077409  77.437837  74.051601  1.025240
# 2030-01-01  76.868142  78.310364  75.437627  0.913984
# 2040-01-01  77.431037  78.875474  75.817532  1.203671
# 2050-01-01  77.889529  79.593603  76.251766  1.043239
# 2060-01-01  78.465273  79.638074  76.874938  0.962638
# 2070-01-01  79.121582  80.534305  77.611878  0.915799
# 2080-01-01  78.844728  80.686890  77.902334  0.984648
# 2090-01-01  79.082790  80.062305  77.701980  0.847213

# %% [markdown]
# ### 7. Plotting
#
# The plot method on DataFrame is just a simple wrapper around a matplotlib method `plt.plot()`

# %%
#df.image.plot()
df.image.hist()
#dfP['image'].plot.box()

# %%
df.image.plot(figsize=(10, 8), color='#348ABD')
plt.title("CNRM-CM5 RCP 4.5")
plt.ylabel("Temperature (degrees F)")
plt.grid(True)

# %% [markdown]
# Experiment with more examples [here]( http://pandas.pydata.org/pandas-docs/stable/visualization.html)
