# %% [markdown]
# # Get Data for a Location

# %% [markdown]
# Begin by importing the required python modules.

# %%
import requests
import pprint # useful for printing pretty json

# %% [markdown]
# Now, let's get the Raster Series Instance of Annual Average Maximum Temperature for one model (CNRM-CM5) and one scenario (RCP 4.5) from the Cal-Adapt API. Let's look at the `rasters` property.

# %%
# Add the params_str to the url.
response = requests.get('http://api.cal-adapt.org/api/series/tasmax_year_CNRM-CM5_rcp45/')
response.json()
# Out:
# {'begin': '2006-01-01T00:00:00Z',
#  'end': '2100-12-31T00:00:00Z',
#  'name': 'yearly average maximum temperature CNRM-CM5 RCP 4.5',
#  'rasters': ['http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2006/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2007/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2008/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2009/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2010/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2011/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2012/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2013/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2014/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2015/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2016/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2017/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2018/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2019/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2020/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2021/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2022/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2023/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2024/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2025/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2026/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2027/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2028/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2029/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2030/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2031/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2032/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2033/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2034/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2035/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2036/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2037/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2038/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2039/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2040/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2041/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2042/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2043/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2044/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2045/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2046/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2047/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2048/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2049/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2050/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2051/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2052/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2053/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2054/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2055/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2056/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2057/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2058/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2059/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2060/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2061/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2062/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2063/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2064/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2065/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2066/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2067/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2068/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2069/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2070/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2071/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2072/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2073/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2074/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2075/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2076/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2077/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2078/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2079/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2080/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2081/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2082/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2083/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2084/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2085/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2086/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2087/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2088/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2089/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2090/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2091/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2092/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2093/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2094/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2095/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2096/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2097/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2098/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2099/',
#   'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2100/'],
#  'slug': 'tasmax_year_CNRM-CM5_rcp45',
#  'tags': ['climate', 'tasmax', 'temperature'],
#  'url': 'http://api.cal-adapt.org/api/series/tasmax_year_CNRM-CM5_rcp45/'}

# %% [markdown]
# To get a list of all Raster Stores in a Raster Series Instance, append `rasters/` to the url.

# %%
response = requests.get('http://api.cal-adapt.org/api/series/tasmax_year_CNRM-CM5_rcp45/rasters/')
response.json()
# Out:
# {'count': 95,
#  'next': 'http://api.cal-adapt.org/api/series/tasmax_year_CNRM-CM5_rcp45/rasters/?page=2',
#  'previous': None,
#  'results': [{'event': '2006-01-01',
#    'geom': {'coordinates': [[[-124.5625, 31.5625],
#       [-113.375, 31.5625],
#       [-113.375, 43.75],
#       [-124.5625, 43.75],
#       [-124.5625, 31.5625]]],
#     'type': 'Polygon'},
#    'height': 195,
#    'id': 10521,
#    'image': 'http://api.cal-adapt.org/media/img/tasmax_year_CNRM-CM5_rcp45_r1i1p1_2006.LOCA_2016-04-02.16th.CA_NV.tif',
#    'maxval': 307.180908203125,
#    'minval': 279.1251220703125,
#    'name': 'yearly average maximum temperature CNRM-CM5 RCP 4.5',
#    'nodata': 1.0000000150474662e+30,
#    'slug': 'tasmax_year_CNRM-CM5_rcp45_2006',
#    'srs': 'GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433],AUTHORITY["EPSG","4326"]]',
#    'tileurl': 'http://api.cal-adapt.org/tiles/tasmax_year_CNRM-CM5_rcp45_2006/{z}/{x}/{y}.png',
#    'units': 'K',
#    'url': 'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2006/',
#    'width': 179,
#    'xpixsize': 0.0625,
#    'ypixsize': -0.0625},
#   {'event': '2007-01-01',
#    'geom': {'coordinates': [[[-124.5625, 31.5625],
#       [-113.375, 31.5625],
#       [-113.375, 43.75],
#       [-124.5625, 43.75],
#       [-124.5625, 31.5625]]],
#     'type': 'Polygon'},
#    'height': 195,
#    'id': 10522,
#    'image': 'http://api.cal-adapt.org/media/img/tasmax_year_CNRM-CM5_rcp45_r1i1p1_2007.LOCA_2016-04-02.16th.CA_NV.tif',
#    'maxval': 307.52490234375,
#    'minval': 278.38330078125,
#    'name': 'yearly average maximum temperature CNRM-CM5 RCP 4.5',
#    'nodata': 1.0000000150474662e+30,
#    'slug': 'tasmax_year_CNRM-CM5_rcp45_2007',
#    'srs': 'GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433],AUTHORITY["EPSG","4326"]]',
#    'tileurl': 'http://api.cal-adapt.org/tiles/tasmax_year_CNRM-CM5_rcp45_2007/{z}/{x}/{y}.png',
#    'units': 'K',
#    'url': 'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2007/',
#    'width': 179,
#    'xpixsize': 0.0625,
#    'ypixsize': -0.0625},
#   {'event': '2008-01-01',
#    'geom': {'coordinates': [[[-124.5625, 31.5625],
#       [-113.375, 31.5625],
#       [-113.375, 43.75],
#       [-124.5625, 43.75],
#       [-124.5625, 31.5625]]],
#     'type': 'Polygon'},
#    'height': 195,
#    'id': 10523,
#    'image': 'http://api.cal-adapt.org/media/img/tasmax_year_CNRM-CM5_rcp45_r1i1p1_2008.LOCA_2016-04-02.16th.CA_NV.tif',
#    'maxval': 306.0617370605469,
#    'minval': 278.2447509765625,
#    'name': 'yearly average maximum temperature CNRM-CM5 RCP 4.5',
#    'nodata': 1.0000000150474662e+30,
#    'slug': 'tasmax_year_CNRM-CM5_rcp45_2008',
#    'srs': 'GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433],AUTHORITY["EPSG","4326"]]',
#    'tileurl': 'http://api.cal-adapt.org/tiles/tasmax_year_CNRM-CM5_rcp45_2008/{z}/{x}/{y}.png',
#    'units': 'K',
#    'url': 'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2008/',
#    'width': 179,
#    'xpixsize': 0.0625,
#    'ypixsize': -0.0625},
#   {'event': '2009-01-01',
#    'geom': {'coordinates': [[[-124.5625, 31.5625],
#       [-113.375, 31.5625],
#       [-113.375, 43.75],
#       [-124.5625, 43.75],
#       [-124.5625, 31.5625]]],
#     'type': 'Polygon'},
#    'height': 195,
#    'id': 10524,
#    'image': 'http://api.cal-adapt.org/media/img/tasmax_year_CNRM-CM5_rcp45_r1i1p1_2009.LOCA_2016-04-02.16th.CA_NV.tif',
#    'maxval': 306.7236633300781,
#    'minval': 277.72564697265625,
#    'name': 'yearly average maximum temperature CNRM-CM5 RCP 4.5',
#    'nodata': 1.0000000150474662e+30,
#    'slug': 'tasmax_year_CNRM-CM5_rcp45_2009',
#    'srs': 'GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433],AUTHORITY["EPSG","4326"]]',
#    'tileurl': 'http://api.cal-adapt.org/tiles/tasmax_year_CNRM-CM5_rcp45_2009/{z}/{x}/{y}.png',
#    'units': 'K',
#    'url': 'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2009/',
#    'width': 179,
#    'xpixsize': 0.0625,
#    'ypixsize': -0.0625},
#   {'event': '2010-01-01',
#    'geom': {'coordinates': [[[-124.5625, 31.5625],
#       [-113.375, 31.5625],
#       [-113.375, 43.75],
#       [-124.5625, 43.75],
#       [-124.5625, 31.5625]]],
#     'type': 'Polygon'},
#    'height': 195,
#    'id': 10525,
#    'image': 'http://api.cal-adapt.org/media/img/tasmax_year_CNRM-CM5_rcp45_r1i1p1_2010.LOCA_2016-04-02.16th.CA_NV.tif',
#    'maxval': 307.107421875,
#    'minval': 279.63714599609375,
#    'name': 'yearly average maximum temperature CNRM-CM5 RCP 4.5',
#    'nodata': 1.0000000150474662e+30,
#    'slug': 'tasmax_year_CNRM-CM5_rcp45_2010',
#    'srs': 'GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433],AUTHORITY["EPSG","4326"]]',
#    'tileurl': 'http://api.cal-adapt.org/tiles/tasmax_year_CNRM-CM5_rcp45_2010/{z}/{x}/{y}.png',
#    'units': 'K',
#    'url': 'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2010/',
#    'width': 179,
#    'xpixsize': 0.0625,
#    'ypixsize': -0.0625},
#   {'event': '2011-01-01',
#    'geom': {'coordinates': [[[-124.5625, 31.5625],
#       [-113.375, 31.5625],
#       [-113.375, 43.75],
#       [-124.5625, 43.75],
#       [-124.5625, 31.5625]]],
#     'type': 'Polygon'},
#    'height': 195,
#    'id': 10526,
#    'image': 'http://api.cal-adapt.org/media/img/tasmax_year_CNRM-CM5_rcp45_r1i1p1_2011.LOCA_2016-04-02.16th.CA_NV.tif',
#    'maxval': 306.43963623046875,
#    'minval': 278.2750244140625,
#    'name': 'yearly average maximum temperature CNRM-CM5 RCP 4.5',
#    'nodata': 1.0000000150474662e+30,
#    'slug': 'tasmax_year_CNRM-CM5_rcp45_2011',
#    'srs': 'GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433],AUTHORITY["EPSG","4326"]]',
#    'tileurl': 'http://api.cal-adapt.org/tiles/tasmax_year_CNRM-CM5_rcp45_2011/{z}/{x}/{y}.png',
#    'units': 'K',
#    'url': 'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2011/',
#    'width': 179,
#    'xpixsize': 0.0625,
#    'ypixsize': -0.0625},
#   {'event': '2012-01-01',
#    'geom': {'coordinates': [[[-124.5625, 31.5625],
#       [-113.375, 31.5625],
#       [-113.375, 43.75],
#       [-124.5625, 43.75],
#       [-124.5625, 31.5625]]],
#     'type': 'Polygon'},
#    'height': 195,
#    'id': 10527,
#    'image': 'http://api.cal-adapt.org/media/img/tasmax_year_CNRM-CM5_rcp45_r1i1p1_2012.LOCA_2016-04-02.16th.CA_NV.tif',
#    'maxval': 307.35198974609375,
#    'minval': 278.5373840332031,
#    'name': 'yearly average maximum temperature CNRM-CM5 RCP 4.5',
#    'nodata': 1.0000000150474662e+30,
#    'slug': 'tasmax_year_CNRM-CM5_rcp45_2012',
#    'srs': 'GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433],AUTHORITY["EPSG","4326"]]',
#    'tileurl': 'http://api.cal-adapt.org/tiles/tasmax_year_CNRM-CM5_rcp45_2012/{z}/{x}/{y}.png',
#    'units': 'K',
#    'url': 'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2012/',
#    'width': 179,
#    'xpixsize': 0.0625,
#    'ypixsize': -0.0625},
#   {'event': '2013-01-01',
#    'geom': {'coordinates': [[[-124.5625, 31.5625],
#       [-113.375, 31.5625],
#       [-113.375, 43.75],
#       [-124.5625, 43.75],
#       [-124.5625, 31.5625]]],
#     'type': 'Polygon'},
#    'height': 195,
#    'id': 10528,
#    'image': 'http://api.cal-adapt.org/media/img/tasmax_year_CNRM-CM5_rcp45_r1i1p1_2013.LOCA_2016-04-02.16th.CA_NV.tif',
#    'maxval': 307.0390319824219,
#    'minval': 278.5429992675781,
#    'name': 'yearly average maximum temperature CNRM-CM5 RCP 4.5',
#    'nodata': 1.0000000150474662e+30,
#    'slug': 'tasmax_year_CNRM-CM5_rcp45_2013',
#    'srs': 'GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433],AUTHORITY["EPSG","4326"]]',
#    'tileurl': 'http://api.cal-adapt.org/tiles/tasmax_year_CNRM-CM5_rcp45_2013/{z}/{x}/{y}.png',
#    'units': 'K',
#    'url': 'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2013/',
#    'width': 179,
#    'xpixsize': 0.0625,
#    'ypixsize': -0.0625},
#   {'event': '2014-01-01',
#    'geom': {'coordinates': [[[-124.5625, 31.5625],
#       [-113.375, 31.5625],
#       [-113.375, 43.75],
#       [-124.5625, 43.75],
#       [-124.5625, 31.5625]]],
#     'type': 'Polygon'},
#    'height': 195,
#    'id': 10529,
#    'image': 'http://api.cal-adapt.org/media/img/tasmax_year_CNRM-CM5_rcp45_r1i1p1_2014.LOCA_2016-04-02.16th.CA_NV.tif',
#    'maxval': 306.3819274902344,
#    'minval': 278.373046875,
#    'name': 'yearly average maximum temperature CNRM-CM5 RCP 4.5',
#    'nodata': 1.0000000150474662e+30,
#    'slug': 'tasmax_year_CNRM-CM5_rcp45_2014',
#    'srs': 'GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433],AUTHORITY["EPSG","4326"]]',
#    'tileurl': 'http://api.cal-adapt.org/tiles/tasmax_year_CNRM-CM5_rcp45_2014/{z}/{x}/{y}.png',
#    'units': 'K',
#    'url': 'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2014/',
#    'width': 179,
#    'xpixsize': 0.0625,
#    'ypixsize': -0.0625},
#   {'event': '2015-01-01',
#    'geom': {'coordinates': [[[-124.5625, 31.5625],
#       [-113.375, 31.5625],
#       [-113.375, 43.75],
#       [-124.5625, 43.75],
#       [-124.5625, 31.5625]]],
#     'type': 'Polygon'},
#    'height': 195,
#    'id': 10530,
#    'image': 'http://api.cal-adapt.org/media/img/tasmax_year_CNRM-CM5_rcp45_r1i1p1_2015.LOCA_2016-04-02.16th.CA_NV.tif',
#    'maxval': 306.65069580078125,
#    'minval': 277.66424560546875,
#    'name': 'yearly average maximum temperature CNRM-CM5 RCP 4.5',
#    'nodata': 1.0000000150474662e+30,
#    'slug': 'tasmax_year_CNRM-CM5_rcp45_2015',
#    'srs': 'GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433],AUTHORITY["EPSG","4326"]]',
#    'tileurl': 'http://api.cal-adapt.org/tiles/tasmax_year_CNRM-CM5_rcp45_2015/{z}/{x}/{y}.png',
#    'units': 'K',
#    'url': 'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2015/',
#    'width': 179,
#    'xpixsize': 0.0625,
#    'ypixsize': -0.0625}]}

# %% [markdown]
# There are a total of 95 Raster Stores in this Raster Series Instance. By default only 10 are returned. You can use the `pagesize` query parameter to get more records with one request.

# %%
response = requests.get('http://api.cal-adapt.org/api/series/tasmax_year_CNRM-CM5_rcp45/rasters/?pagesize=95')

# It is a good idea to check there were no problems with the request.
if response.ok:
    data = response.json()
    # Get a list of Raster Stores from results property of data object
    results = data['results']
    # Print the first item in list
    pprint.pprint(results[0])
    # Print a blank line
    print()
    # Iterate through the list and print the event property of each Raster Store
    for item in results:
        print(item['event'])
# Out:
# {'event': '2006-01-01',
#  'geom': {'coordinates': [[[-124.5625, 31.5625],
#                            [-113.375, 31.5625],
#                            [-113.375, 43.75],
#                            [-124.5625, 43.75],
#                            [-124.5625, 31.5625]]],
#           'type': 'Polygon'},
#  'height': 195,
#  'id': 10521,
#  'image': 'http://api.cal-adapt.org/media/img/tasmax_year_CNRM-CM5_rcp45_r1i1p1_2006.LOCA_2016-04-02.16th.CA_NV.tif',
#  'maxval': 307.180908203125,
#  'minval': 279.1251220703125,
#  'name': 'yearly average maximum temperature CNRM-CM5 RCP 4.5',
#  'nodata': 1.0000000150474662e+30,
#  'slug': 'tasmax_year_CNRM-CM5_rcp45_2006',
#  'srs': 'GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS '
#         '84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433],AUTHORITY["EPSG","4326"]]',
#  'tileurl': 'http://api.cal-adapt.org/tiles/tasmax_year_CNRM-CM5_rcp45_2006/{z}/{x}/{y}.png',
#  'units': 'K',
#  'url': 'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2006/',
#  'width': 179,
#  'xpixsize': 0.0625,
#  'ypixsize': -0.0625}
#
# 2006-01-01
# 2007-01-01
# 2008-01-01
# 2009-01-01
# 2010-01-01
# 2011-01-01
# 2012-01-01
# 2013-01-01
# 2014-01-01
# 2015-01-01
# 2016-01-01
# 2017-01-01
# 2018-01-01
# 2019-01-01
# 2020-01-01
# 2021-01-01
# 2022-01-01
# 2023-01-01
# 2024-01-01
# 2025-01-01
# 2026-01-01
# 2027-01-01
# 2028-01-01
# 2029-01-01
# 2030-01-01
# 2031-01-01
# 2032-01-01
# 2033-01-01
# 2034-01-01
# 2035-01-01
# 2036-01-01
# 2037-01-01
# 2038-01-01
# 2039-01-01
# 2040-01-01
# 2041-01-01
# 2042-01-01
# 2043-01-01
# 2044-01-01
# 2045-01-01
# 2046-01-01
# 2047-01-01
# 2048-01-01
# 2049-01-01
# 2050-01-01
# 2051-01-01
# 2052-01-01
# 2053-01-01
# 2054-01-01
# 2055-01-01
# 2056-01-01
# 2057-01-01
# 2058-01-01
# 2059-01-01
# 2060-01-01
# 2061-01-01
# 2062-01-01
# 2063-01-01
# 2064-01-01
# 2065-01-01
# 2066-01-01
# 2067-01-01
# 2068-01-01
# 2069-01-01
# 2070-01-01
# 2071-01-01
# 2072-01-01
# 2073-01-01
# 2074-01-01
# 2075-01-01
# 2076-01-01
# 2077-01-01
# 2078-01-01
# 2079-01-01
# 2080-01-01
# 2081-01-01
# 2082-01-01
# 2083-01-01
# 2084-01-01
# 2085-01-01
# 2086-01-01
# 2087-01-01
# 2088-01-01
# 2089-01-01
# 2090-01-01
# 2091-01-01
# 2092-01-01
# 2093-01-01
# 2094-01-01
# 2095-01-01
# 2096-01-01
# 2097-01-01
# 2098-01-01
# 2099-01-01
# 2100-01-01

# %% [markdown]
# ### Your turn
#
# 1. In the `results` loop in above cell print other properties of `item`. E.g.:
#     - `print(item['image'])`

# %% [markdown]
# ### Introducing the `g` parameter

# %% [markdown]
# By default, `image` field in a Raster Store Instance points to the entire geotiff file, e.g. `'http://api.cal-adapt.org/media/img/tasmax_year_CNRM-CM5_rcp45_r1i1p1_2006.LOCA_2016-04-02.16th.CA_NV.tif`. To get the data for a specific location we need to give the API a geometry object representing that location. The API can read geometry in several different formats including GeoJSON, WKT. For this exercise we will use GeoJSON.
#
# You also need to tell the API what format you want your data in. You can specify format by adding a `format` parameter to the query, e.g. `http://api.cal-adapt.org/api/series/tasmax_year_CNRM-CM5_rcp45/rasters/?pagesize=95&format=json`. Another way to do it is by sending a [HTTP header](https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers) with the request, which is what we do below.

# %%
# Query parameters dict
params = {
    'pagesize': 100,
    'g': '{"type":"Point","coordinates":[-121.4687,38.5938]}'
}
url = 'http://api.cal-adapt.org/api/series/tasmax_year_CNRM-CM5_rcp45/rasters/'

# Add HTTP header
headers = {'ContentType': 'json'}

# Make request
response = requests.get(url, params=params, headers=headers)

# It is a good idea to check there were no problems with the request.
if response.ok:
    data = response.json()
    # Get a list of Raster Stores
    results = data['results']
    print('First Raster Store object:')
    pprint.pprint(results[0])
    print()
    print('Timeseries for the grid cell at this point:')
    # Iterate through the list and print the event and image property of each Raster Store
    for item in results:
        print('year:', item['event'], 'value:', item['image'], item['units'])
# Out:
# First Raster Store object:
# {'event': '2006-01-01',
#  'geom': {'coordinates': [[[-124.5625, 31.5625],
#                            [-113.375, 31.5625],
#                            [-113.375, 43.75],
#                            [-124.5625, 43.75],
#                            [-124.5625, 31.5625]]],
#           'type': 'Polygon'},
#  'height': 195,
#  'id': 10521,
#  'image': 297.9866027832031,
#  'maxval': 307.180908203125,
#  'minval': 279.1251220703125,
#  'name': 'yearly average maximum temperature CNRM-CM5 RCP 4.5',
#  'nodata': 1.0000000150474662e+30,
#  'slug': 'tasmax_year_CNRM-CM5_rcp45_2006',
#  'srs': 'GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS '
#         '84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433],AUTHORITY["EPSG","4326"]]',
#  'tileurl': 'http://api.cal-adapt.org/tiles/tasmax_year_CNRM-CM5_rcp45_2006/{z}/{x}/{y}.png',
#  'units': 'K',
#  'url': 'http://api.cal-adapt.org/api/rstores/tasmax_year_CNRM-CM5_rcp45_2006/',
#  'width': 179,
#  'xpixsize': 0.0625,
#  'ypixsize': -0.0625}
#
# Timeseries for the grid cell at this point:
# year: 2006-01-01 value: 297.9866027832031 K
# year: 2007-01-01 value: 297.7721862792969 K
# year: 2008-01-01 value: 297.99554443359375 K
# year: 2009-01-01 value: 297.1314392089844 K
# year: 2010-01-01 value: 298.72271728515625 K
# year: 2011-01-01 value: 297.864990234375 K
# year: 2012-01-01 value: 298.1152038574219 K
# year: 2013-01-01 value: 298.7023010253906 K
# year: 2014-01-01 value: 298.2464599609375 K
# year: 2015-01-01 value: 297.06353759765625 K
# year: 2016-01-01 value: 297.49456787109375 K
# year: 2017-01-01 value: 297.77325439453125 K
# year: 2081-01-01 value: 298.7219543457031 K
# year: 2082-01-01 value: 300.1182861328125 K
# year: 2083-01-01 value: 299.2787780761719 K
# year: 2084-01-01 value: 299.4695739746094 K
# year: 2085-01-01 value: 298.84100341796875 K
# year: 2086-01-01 value: 300.2335510253906 K
# year: 2087-01-01 value: 299.0711669921875 K
# year: 2088-01-01 value: 298.62188720703125 K
# year: 2089-01-01 value: 298.8928527832031 K
# year: 2090-01-01 value: 298.57904052734375 K
# year: 2091-01-01 value: 299.4579772949219 K
# year: 2092-01-01 value: 299.6512145996094 K
# year: 2093-01-01 value: 299.1769104003906 K
# year: 2094-01-01 value: 299.8573913574219 K
# year: 2095-01-01 value: 299.9429931640625 K
# year: 2096-01-01 value: 299.2073669433594 K
# year: 2097-01-01 value: 298.531494140625 K
# year: 2098-01-01 value: 299.60150146484375 K
# year: 2099-01-01 value: 299.67681884765625 K
# year: 2100-01-01 value: 299.32452392578125 K

# %% [markdown]
# ### Your turn
#
# 1. Try another location by changing the coordinate pair in `params.g` in the above cell. The spatial extent available on Cal-Adapt covers entire state of California and Nevada and parts of Oregon, Mexico and Arizona.
#
#
# ### Get data for an area
#
# You can also pass in polygon geometry. A polygon can span multiple grid cells (the grid is ~ 6km x 6km). With polygon geometry you can also provide a `stat` parameter which will aggregate data from all grid cells intersected by the polygon. The `stat` parameter can take the value `mean`, `max`, `min`.

# %%
g = '{"type":"Polygon","coordinates":[[[-122.30598,37.76881],[-122.22942,37.76881],[-122.229423,37.83337],[-122.305984,37.83337],[-122.305984,37.76881]]]}'
params = {
    'pagesize': 100,
    'g': g,
    'stat': 'mean'
}
url = 'http://api.cal-adapt.org/api/series/tasmax_year_CNRM-CM5_rcp45/rasters/'

# HTTP header
headers = {'ContentType': 'json'}

# Make request
response = requests.get(url, params=params, headers=headers)

# It is a good idea to check there were no problems with the request.
if response.ok:
    data = response.json()
    # Get a list of Raster Stores
    results = data['results']
    # Iterate through the list and print the event and image property of each Raster Store
    for item in results:
        print('year:', item['event'], 'value:', item['image'], item['units'])
# Out:
# year: 2006-01-01 value: 292.9714660644531 K
# year: 2007-01-01 value: 293.04962158203125 K
# year: 2008-01-01 value: 292.99505615234375 K
# year: 2009-01-01 value: 291.9574279785156 K
# year: 2010-01-01 value: 293.55584716796875 K
# year: 2011-01-01 value: 292.706298828125 K
# year: 2012-01-01 value: 292.907958984375 K
# year: 2013-01-01 value: 293.43463134765625 K
# year: 2014-01-01 value: 293.3565673828125 K
# year: 2015-01-01 value: 292.2034912109375 K
# year: 2016-01-01 value: 292.6650695800781 K
# year: 2017-01-01 value: 292.90478515625 K
# year: 2018-01-01 value: 292.09619140625 K
# year: 2019-01-01 value: 292.6543273925781 K
# year: 2020-01-01 value: 291.68157958984375 K
# year: 2021-01-01 value: 291.77410888671875 K
# year: 2022-01-01 value: 292.9532470703125 K
# year: 2023-01-01 value: 292.922119140625 K
# year: 2024-01-01 value: 292.8807678222656 K
# year: 2025-01-01 value: 292.5096435546875 K
# year: 2026-01-01 value: 292.69256591796875 K
# year: 2090-01-01 value: 293.48187255859375 K
# year: 2091-01-01 value: 293.8209228515625 K
# year: 2092-01-01 value: 293.68475341796875 K
# year: 2093-01-01 value: 293.8141784667969 K
# year: 2094-01-01 value: 294.2667236328125 K
# year: 2095-01-01 value: 294.046142578125 K
# year: 2096-01-01 value: 293.3733825683594 K
# year: 2097-01-01 value: 293.4162902832031 K
# year: 2098-01-01 value: 293.8945007324219 K
# year: 2099-01-01 value: 294.1444396972656 K
# year: 2100-01-01 value: 293.9606628417969 K

# %% [markdown]
# ### Use vector data from Cal-Adapt API
#
# The API contains several boundary datasets. You can use polygon geometry from these vector resources instead of providing your own. For an example see notebook - [get_polygon_geometry_from_api](get_polygon_geometry_from_api.ipynb)

# %% [markdown]
# ### Get data for a time slice
#
# You can get data for a time slice instead of the full timeseries by substituting `rasters/` with a `begin-date/end-date/`.

# %%
g = '{"type":"Polygon","coordinates":[[[-122.30598,37.76881],[-122.22942,37.76881],[-122.229423,37.83337],[-122.305984,37.83337],[-122.305984,37.76881]]]}'
params = {
    'pagesize': 100,
    'g': g,
    'stat': 'mean'
}
url = 'http://api.cal-adapt.org/api/series/tasmax_year_CNRM-CM5_rcp45/2070-01-01/2099-01-01/'

# Add HTTP header
headers = {'ContentType': 'json'}

# Make request
response = requests.get(url, params=params, headers=headers)

# It is a good idea to check there were no problems with the request.
if response.ok:
    data = response.json()
    # Get a list of Raster Stores from results property of data object
    results = data['results']
    # Iterate through the list and print the event and image property of each Raster Store
    for item in results:
        print('year:', item['event'], 'value:', item['image'], item['units'])
# Out:
# year: 2070-01-01 value: 294.0802307128906 K
# year: 2071-01-01 value: 293.8209533691406 K
# year: 2072-01-01 value: 294.4517517089844 K
# year: 2073-01-01 value: 294.20672607421875 K
# year: 2074-01-01 value: 293.5401916503906 K
# year: 2075-01-01 value: 293.53826904296875 K
# year: 2076-01-01 value: 294.32012939453125 K
# year: 2077-01-01 value: 293.42315673828125 K
# year: 2078-01-01 value: 293.40582275390625 K
# year: 2079-01-01 value: 293.44085693359375 K
# year: 2080-01-01 value: 293.2380676269531 K
# year: 2081-01-01 value: 293.19512939453125 K
# year: 2082-01-01 value: 294.371826171875 K
# year: 2083-01-01 value: 293.8005065917969 K
# year: 2084-01-01 value: 293.5521545410156 K
# year: 2085-01-01 value: 293.533935546875 K
# year: 2086-01-01 value: 294.35498046875 K
# year: 2087-01-01 value: 293.5646667480469 K
# year: 2088-01-01 value: 293.3834533691406 K
# year: 2089-01-01 value: 293.0765380859375 K
# year: 2090-01-01 value: 293.48187255859375 K
# year: 2091-01-01 value: 293.8209228515625 K
# year: 2092-01-01 value: 293.68475341796875 K
# year: 2093-01-01 value: 293.8141784667969 K
# year: 2094-01-01 value: 294.2667236328125 K
# year: 2095-01-01 value: 294.046142578125 K
# year: 2096-01-01 value: 293.3733825683594 K
# year: 2097-01-01 value: 293.4162902832031 K
# year: 2098-01-01 value: 293.8945007324219 K
# year: 2099-01-01 value: 294.1444396972656 K
